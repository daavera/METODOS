# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import matplotlib as mpl
from mpl_toolkits.mplot3d import Axes3D

# %%
datos = pd.read_csv("datos_planetas.csv",header=0)

# %%
datos.tail()
# Out:
#      index         X         Y         Z        X2        Y2        Z2
# 995    995  0.002550  0.006238 -0.000139 -0.751366  10.62157  0.936428
# 996    996  0.002548  0.006241 -0.000139 -0.999261  10.65321  0.961755
# 997    997  0.002548  0.006243 -0.000139 -0.753603  10.64298  0.938382
# 998    998  0.002546  0.006246 -0.000139 -1.001993  10.67466  0.963758
# 999    999  0.002546  0.006248 -0.000139 -0.755840  10.66438  0.940335

# %%
x = datos['X']
y = datos['Y']
z = datos['Z']
x2 = datos['X2']
y2 = datos['Y2']
z2 = datos['Z2']

# %%
mpl.rcParams['legend.fontsize'] = 10
fig = plt.figure()
ax = fig.gca(projection='3d')
ax.scatter(x, y, z, linewidth=0.6, label='sol', color='darkslateblue')
ax.scatter(x2, y2, z2, linewidth=0.6, label='tierra', color='b')
ax.legend()
plt.show()

# %%
plt.plot(z,x)
plt.plot(z2,x2, c='r')
plt.show()
