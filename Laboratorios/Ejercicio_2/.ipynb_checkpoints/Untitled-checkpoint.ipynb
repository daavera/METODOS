# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
plt.style.use('ggplot')

# %%
datos = pd.read_csv('room-temperature.csv', sep=',')
datos = datos.ix[:,1:]
# Out:
# /Users/Prueba/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:2: DeprecationWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/indexing.html#deprecate_ix

# %%
datos
# Out:
#      FrontLeft  FrontRight  BackLeft  BackRight
# 0        295.2       297.0     295.8      296.3
# 1        296.2       296.4     296.2      296.3
# 2        297.3       297.5     296.7      297.1
# 3        295.9       296.7     297.4      297.0
# 4        297.2       296.5     297.6      297.4
# 5        296.6       297.7     296.7      296.5
# 6        297.5       297.6     297.5      298.2
# 7        296.0       297.1     297.1      296.5
# 8        297.7       298.1     297.6      297.6
# 9        296.9       299.0     297.0      297.4
# 10       296.7       296.9     297.1      296.5
# 11       297.0       297.0     296.7      296.7
# 12       297.3       297.0     296.1      296.3
# 13       294.8       295.5     295.8      296.6
# 14       296.1       297.0     296.3      296.6
# 15       295.9       295.6     295.5      295.8
# 16       294.9       295.1     295.1      295.7
# 17       295.1       295.7     295.2      295.0
# 18       293.9       295.0     295.2      295.4
# 19       294.8       295.2     295.0      295.1
# 20       294.4       294.4     294.1      294.4
# 21       293.4       294.4     294.1      293.7
# 22       294.6       294.4     294.2      294.5
# 23       292.4       294.6     293.4      293.3
# 24       293.1       294.1     294.0      293.3
# 25       293.6       294.1     293.4      293.0
# 26       292.8       293.9     292.7      293.3
# 27       292.9       293.0     293.4      293.0
# 28       292.7       292.9     292.8      292.3
# 29       292.6       292.6     293.7      292.7
# ..         ...         ...       ...        ...
# 114      295.5       295.2     296.0      296.3
# 115      294.6       294.2     295.4      294.2
# 116      293.9       293.9     293.6      294.4
# 117      293.7       294.2     294.2      294.0
# 118      293.0       293.3     294.2      294.6
# 119      292.7       292.2     293.6      293.3
# 120      292.8       294.1     294.0      292.8
# 121      294.1       292.8     293.5      292.1
# 122      293.1       292.3     293.5      292.4
# 123      294.0       293.3     293.0      293.0
# 124      292.7       293.8     292.1      292.5
# 125      292.7       292.4     293.1      293.5
# 126      292.2       294.2     292.4      292.1
# 127      292.8       292.6     293.3      292.8
# 128      293.5       293.6     293.1      292.2
# 129      293.3       292.6     294.5      292.9
# 130      292.7       293.4     297.4      292.7
# 131      292.1       293.0     292.4      293.0
# 132      292.2       293.2     294.6      292.5
# 133      294.4       293.8     294.0      294.1
# 134      294.7       293.7     294.6      293.5
# 135      294.5       294.1     294.9      293.9
# 136      295.8       294.8     294.0      294.1
# 137      294.4       295.4     294.2      294.4
# 138      295.8       295.6     295.4      295.6
# 139      295.8       294.6     294.8      295.7
# 140      294.8       295.5     294.7      295.6
# 141      295.9       295.8     295.5      295.2
# 142      295.1       296.2     296.0      296.1
# 143      296.2       297.2     296.6      296.0
#
# [144 rows x 4 columns]

# %%
f1, ax = plt.subplots(2,2, figsize=(6,6))
ax[0,0].plot(datos['FrontLeft'])
ax[0,0].set_title('Front Left')

ax[0,1].plot(datos['FrontRight'], c='g')
ax[0,1].set_title('Front Right')

ax[1,0].plot(datos['BackLeft'],c='r')
ax[1,0].set_title('Back Left')

ax[1,1].plot(datos['BackRight'], c='y')
ax[1,1].set_title('Back Right')

plt.tight_layout()
plt.show()
#plt.savefig('temp.png')

# %%
datos_norm = (datos-datos.mean(axis=0))/datos.std(axis=0)
cov = np.cov(datos_norm.T)
print(cov)
# Out:
# [[ 1.          0.85247599  0.55833731  0.60566994]
#  [ 0.85247599  1.          0.58767585  0.63909555]
#  [ 0.55833731  0.58767585  1.          0.88401916]
#  [ 0.60566994  0.63909555  0.88401916  1.        ]]

# %%
values , vectors = np.linalg.eig(cov)
orden = ["primera","segunda","tercera","cuarta"]
for i in range(2):
    print('La %s componente principal es %s con valor %f.' % (orden[i],vectors[:,i],values[i]))
# Out:
# La primera componente principal es [-0.49127375 -0.50211307 -0.49486494 -0.51150881] con valor 3.064320.
# La segunda componente principal es [-0.5308801  -0.47235221  0.53968805  0.4514272 ] con valor 0.675869.

# %%
for i in range(len(values)):
    per = (values[i]*100)/np.sum(values)
    print('La %s componente principal explica el %f porciento de la varianza.' %(orden[i],per))
# Out:
# La primera componente principal explica el 76.608010 porciento de la varianza.
# La segunda componente principal explica el 16.896714 porciento de la varianza.
# La tercera componente principal explica el 3.668610 porciento de la varianza.
# La cuarta componente principal explica el 2.826666 porciento de la varianza.

# %%
f2 = plt.figure(figsize=(10,6))
plt.scatter(datos_norm['FrontRight'],datos_norm['FrontLeft'], c='purple', label ='Datos')
v1 = vectors[0,:2]
v2 = vectors[1,:2]
plt.plot([v1[0],-v1[0]],[v2[0],-v2[0]],marker = 'o', color='greenyellow',label='PCA1')
plt.plot([v1[1],-v1[1]],[v2[1],-v2[1]],marker = 'o', color='orange',label='PCA2')
plt.title('Front Right vs. Front Left')
plt.xlabel('Front Left')
plt.ylabel('Front Right')
plt.legend(loc='upper left')
plt.show()

# %%
f3 = plt.figure(figsize=(10,6))
plt.scatter(datos_norm['BackLeft'],datos_norm['FrontLeft'], c='brown', label='Datos')
V1 = vectors[0,:2]
V2 = vectors[2,:2]
plt.plot([V1[0],-V1[0]], [V2[0] ,-V2[0]], marker = 'o', color='greenyellow',label='PCA1')
plt.plot([V1[1],-V1[1]], [V2[1] ,-V2[1]], marker = 'o', color='orange', label='PCA2')
plt.title('Back Left vs Front Left')
plt.legend(loc='upper left')
plt.xlabel('Front Left')
plt.ylabel('Back Left')
plt.show()
